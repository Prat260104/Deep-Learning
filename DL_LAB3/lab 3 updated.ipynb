# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", x_test.shape)
print("Test labels shape:", y_test.shape)
# Out:
# Training data shape: (60000, 28, 28)
# Training labels shape: (60000,)
# Test data shape: (10000, 28, 28)
# Test labels shape: (10000,)

# %%
# Reshaping for CNN (adding channel dimension)
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1) / 255.0
x_test  = x_test.reshape(x_test.shape[0], 28, 28, 1) / 255.0
print("Reshaped training data:", x_train.shape)
print("Reshaped test data:", x_test.shape)
# Out:
# Reshaped training data: (60000, 28, 28, 1)
# Reshaped test data: (10000, 28, 28, 1)

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
# Set up Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=1)

# Fit the model and pass the early stopping callback
history = model.fit(
    x_train,
    y_train,
    epochs=20,  # Epochs thode zyada rakh dijiye taaki early stopping chance pakad paye
    batch_size=32,
    validation_split=0.1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9134 - loss: 0.2870 - val_accuracy: 0.9800 - val_loss: 0.0712
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9619 - loss: 0.1248 - val_accuracy: 0.9845 - val_loss: 0.0560
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9711 - loss: 0.0956 - val_accuracy: 0.9872 - val_loss: 0.0501
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9751 - loss: 0.0825 - val_accuracy: 0.9875 - val_loss: 0.0435
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9791 - loss: 0.0688 - val_accuracy: 0.9882 - val_loss: 0.0419
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9807 - loss: 0.0629 - val_accuracy: 0.9878 - val_loss: 0.0418
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9829 - loss: 0.0542 - val_accuracy: 0.9915 - val_loss: 0.0392
# Epoch 8/20
# ...

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - accuracy: 0.9874 - loss: 0.0379
# Test Accuracy: 0.9873999953269958

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Training vs Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train Accuracy", "Validation Accuracy"])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Training vs Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train Loss", "Validation Loss"])
plt.grid(True)
plt.show()

# %%
# Generate predictions for the test dataset
predictions = model.predict(x_test)

# Function to plot images and their predicted/true labels
def plot_predictions(images, labels, preds, num_images=10):
    plt.figure(figsize=(15, 6))
    for i in range(num_images):
        plt.subplot(2, 5, i + 1)
        plt.imshow(images[i].reshape(28, 28), cmap='gray')
        
        predicted_label = np.argmax(preds[i])
        true_label = labels[i]
        
        color = 'green' if predicted_label == true_label else 'red'
        
        plt.title(f"Pred: {predicted_label} | True: {true_label}", color=color)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# Plot first 10 test images
plot_predictions(x_test, y_test, predictions, num_images=10)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step

# %% [markdown]
# ### Observation:
#
# After inspecting the dataset shape, the images were reshaped into `(28, 28, 1)` dimensional vectors to be fed into the CNN.
#
# **Evaluation & Architecture:** The model uses Conv2D and MaxPooling2D layers to extract features. To counter potential overfitting, `Dropout` layers were introduced (`Dropout(0.25)` after pooling, and `Dropout(0.5)` after the dense layer).
#
# **Result:** With Dropout, the model generalizes better, and the gap between training and validation accuracy/loss is reduced. Validation loss curves show stability and no major signs of overfitting. The final model yields a solid accuracy on testing data.
